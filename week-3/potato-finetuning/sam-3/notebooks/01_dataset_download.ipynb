# %%
import platform
print(platform.system())
# Out:
# Linux

# %%
# %cd /content
# !rm -rf mccain-internship
# !git clone https://github.com/PushkargithubCSE/mccain-internship.git
# %cd mccain-internship/week-3/potato-finetuning
PROJECT_PATH = "/content/mccain-internship/week-3/potato-finetuning"
# !pwd
# Out:
# /content
# Cloning into 'mccain-internship'...
# remote: Enumerating objects: 558, done.
# remote: Counting objects: 100% (558/558), done.
# remote: Compressing objects: 100% (407/407), done.
# remote: Total 558 (delta 144), reused 502 (delta 94), pack-reused 0 (from 0)
# Receiving objects: 100% (558/558), 24.27 MiB | 19.87 MiB/s, done.
# Resolving deltas: 100% (144/144), done.
# /content/mccain-internship/week-3/potato-finetuning
# /content/mccain-internship/week-3/potato-finetuning

# %%
# !pip install -q roboflow python-dotenv

# %%
api_key_value = "YOUR_ROBOFLOW_API_KEY"  # Replace with your actual Roboflow API key

with open(f"{PROJECT_PATH}/.env", "w") as f:
    f.write(f"ROBOFLOW_API_KEY_1={api_key_value}\n")

print("✓ .env created")
# Out:
# ✓ .env created

# %%
project = rf.workspace("pushkar-chandra").project("segmentation-jajrd")

versions = project.versions()
print(f"Available versions: {len(versions)}")
for v in versions:
    print(f"  - {v.version}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Available versions: 2
#   - 2
#   - 1

# %%
import os
from dotenv import load_dotenv
from roboflow import Roboflow

env_path = os.path.join(PROJECT_PATH, ".env")
load_dotenv(env_path)
api_key = os.getenv('ROBOFLOW_API_KEY_1')

print("Key loaded:", bool(api_key))

rf = Roboflow(api_key=api_key)
project = rf.workspace("pushkar-chandra").project("segmentation-jajrd")
dataset = project.version(2).download("coco-segmentation")

print(f"✓ Dataset ready at: {dataset.location}")
# Out:
# Key loaded: True
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format coco-segmentation in progress : 0.0%
# Version export complete for coco-segmentation format
# Downloading Dataset Version Zip in Segmentation-2 to coco-segmentation:: 100%|██████████| 329/329 [00:00<00:00, 363.36it/s]
# Extracting Dataset Version Zip to Segmentation-2 in coco-segmentation:: 100%|██████████| 20/20 [00:00<00:00, 5232.74it/s]
# ✓ Dataset ready at: /content/mccain-internship/week-3/potato-finetuning/Segmentation-2

# %%
import json

for split in ['train', 'valid', 'test']:
    ann_path = f"{dataset.location}/{split}/_annotations.coco.json"
    if os.path.exists(ann_path):
        with open(ann_path) as f:
            coco_data = json.load(f)
        
        num_with_segmentation = sum(1 for ann in coco_data['annotations'] if len(ann.get('segmentation', [])) > 0)
        
        print(f"[{split.upper()}]")
        print(f"  Images: {len(coco_data['images'])}")
        print(f"  Annotations: {len(coco_data['annotations'])}")
        print(f"  Annotations WITH polygon segmentation: {num_with_segmentation}")
        print()
# Out:
# [TRAIN]
#   Images: 10
#   Annotations: 10
#   Annotations WITH polygon segmentation: 10
#
# [VALID]
#   Images: 3
#   Annotations: 3
#   Annotations WITH polygon segmentation: 3
#
# [TEST]
#   Images: 2
#   Annotations: 2
#   Annotations WITH polygon segmentation: 2

# %%
for split in ['train', 'valid', 'test']:
    ann_path = f"{dataset.location}/{split}/_annotations.coco.json"
    print(f"{split}: exists = {os.path.exists(ann_path)}")
# Out:
# train: exists = True
# valid: exists = True
# test: exists = True
